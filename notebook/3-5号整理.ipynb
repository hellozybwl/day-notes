# %% [markdown]
# # 排列组合原理
#
# ![Screenshot.png](attachment:Screenshot.png)

# %% [markdown]
# # 公式定义
#
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202019-03-02%20%E4%B8%8A%E5%8D%886.54.21.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202019-03-02%20%E4%B8%8A%E5%8D%886.54.21.png)

# %% [markdown]
# # 一张图了解tensorflow中的线性回归工作原理
#
# http://www.shareditor.com/blogshow?blogId=120

# %% [markdown]
# # tensorflow的可视化是使用summary和tensorboard合作完成的.
#
#     with tf.Session() as sess:
#         writer = tf.summary.FileWriter(your_dir, sess.graph)
#
# 命令行运行tensorboard --logdir your_dir,然后浏览器输入127.0.1.1:6006
# 注：tf1.1.0 版本的tensorboard端口换了(0.0.0.0:6006)
# 这样你就可以在tensorboard中看到你的网络结构图了
#
# https://blog.csdn.net/u012436149/article/details/53184847

# %% [markdown]
# # 深入MNIST
#
# http://wiki.jikexueyuan.com/project/tensorflow-zh/tutorials/mnist_beginners.html
# http://wiki.jikexueyuan.com/project/tensorflow-zh/tutorials/mnist_pros.html
